# %% [markdown]
# ## Cleaning our data

# %% [markdown]
# ### Imporing modules and detasets

# %%
# Importing modules 
import pandas as pd

# %%
# Importing the datasets needed 
path = "C:/Users/fredr/OneDrive/Documents/Master/Semester_1/Visual_analytics/Project/"
df_all_data = pd.read_csv(path + "gvc_trade_WITS-update.csv")
df_sectors = pd.read_csv(path + "sector-tiva.csv", sep=";") # The seperator for this dataset is ";"
df_countries = pd.read_csv(path + "gvc-countries.csv")

# %% [markdown]
# ### Filtering the dataset

# %%
# Create a list of the columns to be dropped
uneccesary_col = ["gtrade_fin", "gtrade_int", "traditional_trade_int", "traditional_trade_fin", "gvcbp", "gvcfp", "gvcmix"]

# Drop the specified columns
df_data = df_all_data.drop(uneccesary_col, axis=1)

# %%
# Filtering dat for a range of years 

# Creating a index of year that we want dropped 
before95_index = df_data[df_data["t"] < 1995].index 

# Dropping the index 
df_data.drop(before95_index, inplace = True)

# %%
# Specify the names of the columns to use for the merge
left_on = ["sect", "source"]
right_on = ["sect", "source"]
# Perform the merge
df_filtered = pd.merge(df_data, df_sectors, left_on=left_on, right_on=right_on, how = "left")

# Drop uncessesary columns
df_filtered.drop(["sect"], axis=1, inplace=True)

# %%
# Change country abbreviation to ful name (eg. GER --> Germany)

# Use a dictionary comprehension to create a dictionary from the dataframe
dic_country_name = {row["country"]: row["country_name"] for _, row in df_countries.iterrows()}

# change country abbreviation to full name in exp and imp column
for col in ["exp", "imp"]:
    df_filtered[col] = df_filtered[col].map(dic_country_name)

# %% [markdown]
# ### Cleaning the data

# %%
# Getting a look at the filtered data 
df_filtered.sample(15)
# Out:
#                        exp             imp     t source    gtrade  \
# 10988850          Suriname  Cayman Islands  2011   eora  0.004564
# 24745815            Brazil           Japan  2007   tiva  3.605302
# 5010085              Haiti         Morocco  2007   eora  0.013367
# 30893842       Switzerland         Senegal  2006   tiva  0.796845
# 6373021         Seychelles          Taiwan  1996   eora  0.017408
# 12106561               UAE     New Zealand  1999   eora  0.013360
# 13951501           Andorra         Bolivia  1995   eora  0.004879
# 3454394   Papua New Guinea         Vanuatu  1998   eora  0.004221
# 9646797            Croatia          Belize  2012   eora  0.011999
# 31002402         Lithuania           Chile  2006   tiva  0.035767
# 2169255            Georgia           Italy  2015   eora  0.028591
# 19301086       South Sudan    Saudi Arabia  2005   eora  0.009424
# 7314306               Togo      Kazakhstan  2003   eora  0.012700
# 23127590        Luxembourg        Bulgaria  2016    adb  5.944359
# 20106738            Mexico         Denmark  2004  wiodo  1.368540
#
#           traditional_trade       gvc                                 category
# 10988850           0.003120  0.001444                                      NaN
# 24745815           3.073243  0.532059  Human health and social work activities
# 5010085            0.008678  0.004689                                      NaN
# 30893842           0.591932  0.204913                       Telecommunications
# 6373021            0.007393  0.010015                                      NaN
# 12106561          -0.001220  0.014580                                      NaN
# 13951501           0.003022  0.001858                                      NaN
# 3454394            0.002283  0.001938                                      NaN
# 9646797            0.006736  0.005263                                      NaN
# 31002402           0.019205  0.016562              Paper products and printing
# 2169255           -0.223404  0.251995                                      NaN
# 19301086           0.003070  0.006355                                      NaN
# 7314306            0.007435  0.005265                                      NaN
# 23127590           0.479492  5.464867                                      NaN
# 20106738           0.594020  0.774520                                      NaN

# %%
# Cheking for null values 
df_filtered.isnull().sum()
# Out:
# exp                    130638
# imp                    130638
# t                           0
# source                      0
# gtrade                      0
# traditional_trade           0
# gvc                         0
# category             24307114
# dtype: int64

# %%
# Cheking if the source is correct 
df_filtered.groupby("source").count()
# Out:
#              exp       imp         t    gtrade  traditional_trade       gvc  \
# source
# adb      2083725   2083725   2083725   2083725            2083725   2083725
# eora    19503666  19503666  19503666  19503666           19503666  19503666
# tiva     6846840   6846840   6936930   6936930            6936930   6936930
# wiodlr     89700     89700     93288     93288              93288     93288
# wiodn    1589280   1589280   1626240   1626240            1626240   1626240
# wiodo    1000195   1000195   1000195   1000195            1000195   1000195
#
#         category
# source
# adb            0
# eora           0
# tiva     6936930
# wiodlr         0
# wiodn          0
# wiodo          0

# %% [markdown]
# When we check for null values, we have 130,638 null values in "exp" and "imp". This is because TIVA mainly focuses on OECD countries and their repsected trading partners, and therefore, the null values is all the other countires in the world. We, therefore, categorise these as "Rest of the World". Furthermore, we have null values in the category column. This is mainly becuase we use "left join" when we merge the sectors with our main dataset. Since we will mainly focus on TIVA we will, therefore, dropp all the other sectors.

# %%
# Chaning the null values to "Rest of the World"
df_filtered["exp"].fillna("Rest of the World", inplace = True)
df_filtered["imp"].fillna("Rest of the World", inplace = True)

# %%
# Defining the values we want to be droppped 
Dropp_sectors = ["adb", "eora", "wiodlr", "wiodn", "wiodo"]

# Dropping the rows that contain these values
df_clean = df_filtered[df_filtered.source.isin(Dropp_sectors) == False]

# %%
# Chainging "Viet Nam" to Vietnam
df_clean["exp"] = df_clean["exp"].replace(["Viet Nam"], "Vietnam")
df_clean["imp"] = df_clean["imp"].replace(["Viet Nam"], "Vietnam")
# Out:
# C:\Users\fredr\AppData\Local\Temp\ipykernel_20400\424035730.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean["exp"] = df_clean["exp"].replace(["Viet Nam"], "Vietnam")
# C:\Users\fredr\AppData\Local\Temp\ipykernel_20400\424035730.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean["imp"] = df_clean["imp"].replace(["Viet Nam"], "Vietnam")

# %%
# Chainging the column names 
df_clean.rename(columns = {"exp":"Export", "imp":"Import", "t":"Year", "source":"Source", "gtrade":"Gross Trade", "traditional_trade":"Traditional Trade", "gvc":"GVC", "category":"Category"}, inplace = True)
# Out:
# C:\Users\fredr\AppData\Local\Temp\ipykernel_20400\89940070.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean.rename(columns = {"exp":"Export", "imp":"Import", "t":"Year", "source":"Source", "gtrade":"Gross Trade", "traditional_trade":"Traditional Trade", "gvc":"GVC", "category":"Category"}, inplace = True)

# %%
# Removing where export and import is the same country 
df_clean = df_clean[df_clean["Export"] != df_clean["Import"]]

# %%
# Looking at the clean dataframe
df_clean.sample(15)
# Out:
#                 Export        Import  Year Source  Gross Trade  \
# 30297105       Ireland   New Zealand  2011   tiva     0.039434
# 25391542       Austria           USA  2013   tiva  1085.041539
# 26810492     Hong Kong        Israel  2002   tiva    23.183938
# 27529577    Bangladesh         China  1996   tiva     0.005726
# 28969420        Israel      Cambodia  2019   tiva     0.219980
# 25635737       Vietnam         India  2013   tiva     0.630105
# 31065955       Finland        Latvia  2020   tiva     6.444260
# 29247719         Japan      Slovakia  2000   tiva     4.361217
# 26185550     Australia        Brazil  2014   tiva     0.564677
# 28147247       Croatia       Germany  2017   tiva    16.522643
# 29234909        Israel   Switzerland  2000   tiva    31.540068
# 30069236    Luxembourg       Ukraine  1998   tiva     0.048295
# 24359085  Cote dIvoire  South Africa  2010   tiva     0.080004
# 25357676        Taiwan  Cote dIvoire  2008   tiva     0.149769
# 28799287       Senegal       Ireland  1995   tiva     0.004771
#
#           Traditional Trade         GVC  \
# 30297105           0.036008    0.003426
# 25391542         584.443748  500.597791
# 26810492          12.592138   10.591800
# 27529577           0.004555    0.001171
# 28969420           0.195783    0.024197
# 25635737           0.456063    0.174042
# 31065955           4.309351    2.134909
# 29247719           2.406615    1.954602
# 26185550           0.438793    0.125884
# 28147247           8.941191    7.581452
# 29234909          21.961506    9.578562
# 30069236           0.014169    0.034126
# 24359085           0.070915    0.009089
# 25357676           0.094807    0.054962
# 28799287           0.001752    0.003019
#
#                                                    Category
# 30297105            Human health and social work activities
# 25391542                       Machinery and equipment, nec
# 26810492                                      Air transport
# 27529577                Other non-metallic mineral products
# 28969420                             Real estate activities
# 25635737                           Other service activities
# 31065955  Manufacturing nec; repair and installation of ...
# 29247719                     Chemical and chemical products
# 26185550                            Fishing and aquaculture
# 28147247                Other non-metallic mineral products
# 29234909  Wholesale and retail trade; repair of motor ve...
# 30069236                 Wood and products of wood and cork
# 24359085            Human health and social work activities
# 25357676  Professional, scientific and technical activities
# 28799287  Mining and quarrying, non-energy producing pro...

# %% [markdown]
# ### Saving the cleaned dataset

# %%
# Save the clean dataset as a csv file
# df_clean.to_csv("C:/Users/fredr/OneDrive/Documents/Master/Semester_1/Visual_analytics/Project/cleaned_data.csv")
